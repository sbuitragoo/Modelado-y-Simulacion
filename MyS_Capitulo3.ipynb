# %% [markdown]
# <a href="https://colab.research.google.com/github/sbuitragoo/Modelado-y-Simulacion/blob/main/MyS_Capitulo3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Modelado y Simulación**
#
# ## _Nonlinear Dynamics and Chaos_ - Capitulo 3
#
# ### Santiago Buitrago Osorio

# %%
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Libraries

# %%
def plotVF(f,critical_values,xi,xf,n,ti,tf):
  b = 0
  x = np.linspace(xi,xf,100)
  plt.figure(figsize=(int(5*len(critical_values)),10))
  p = 1
  for i in critical_values:
    plt.subplot(2,len(critical_values),p)
    p = p+1
    plt.plot(x,f(t=0,x=x,r=i,b=0))
    plt.axhline(0,color='black')
    plt.axvline(0,color='black')
    plt.title(f"$r = {i}$",fontsize=20)
    plt.xlabel("$x$")
    plt.ylabel("$\dot x$")

    tspam=[ti, tf]
    t=np.linspace(ti,tf,100)
    plt.subplot(2,len(critical_values),p+len(critical_values)-1)
    for x0 in np.linspace(xi,xf,n):
      sol=solve_ivp(f,tspam,[x0],args=(i,b),t_eval=t)
      plt.plot(sol.t, sol.y[0])
      plt.ylim(-10,10)
      plt.xlabel("$t$",fontsize=15)
      plt.ylabel("$x(t)$",fontsize=15)
      plt.grid('on')
  plt.tight_layout()

# %% [markdown]
# # 3.1 Saddle-Node Bifurcation

# %% [markdown]
# ## 3.1.1
# $$\dot{x} = 1 + rx + x^2$$

# %%
def f(t,x,r,b=0):
  return 1 + r*x + x**2


plotVF(f,[-5,-2,0,2,5],-10,10,10,0,2)

# %%
ti=0; tf=100; dt=100
tspam=[ti, tf]
b=0
plt.figure(figsize=(10,6))
for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(f,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(f,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-5, 5, -10, 10])
plt.grid()
plt.xlabel("$r$",fontsize=15)
plt.ylabel("$x*$",fontsize=15)
plt.title("Diagrama de Bifurcación",fontsize=20)
plt.show()

# %% [markdown]
# ## 3.1.2
# $$\dot{x} = r - \cosh{x}$$

# %%
def f(t,x,r,b=0):
  return r - np.cosh(x)

plotVF(f,[-2,1,2],-5,5,15,0,5)

# %%
ti=0; tf=100; dt=100
tspam=[ti, tf]
b=0
plt.figure(figsize=(10,6))
for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(f,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(f,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-5, 5, -10, 10])
plt.grid()
plt.xlabel("$r$",fontsize=15)
plt.ylabel("$x*$",fontsize=15)
plt.title("Diagrama de Bifurcación",fontsize=20)

plt.show()

# %% [markdown]
# ## 3.1.3
# $$\dot{x} = r + x - \ln(x+1)$$

# %%
def f(t,x,r,b=0):
  return r + x - np.log(x+1) 

plotVF(f,[-1,0,2],-0.9,3,10,0,3)

# %%
ti=0; tf=50; dt=100
tspam=[ti, tf]
b=0
plt.figure(figsize=(10,6))
for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-0.9,5,0.7):
    sol=solve_ivp(f,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-0.9,5,0.7):
    sol=solve_ivp(f,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-5, 5, -10, 10])
plt.grid()
plt.xlabel("$r$",fontsize=15)
plt.ylabel("$x*$",fontsize=15)
plt.title("Diagrama de Bifurcación",fontsize=20)
plt.show()

# %% [markdown]
# # 3.2 Transcritical Bifurcation

# %% [markdown]
# ## 3.2.1
# $$rx + x^2$$

# %%
def f(t,x,r,b=0):
  return r*x + x**2 

plotVF(f,[-2,0,2],-3,3,10,0,3)

# %%
ti=0; tf=100; dt=100
tspam=[ti, tf]
b=0
plt.figure(figsize=(10,6))
for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(f,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(f,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-5, 5, -10, 10])
plt.grid()
plt.xlabel("$r$",fontsize=15)
plt.ylabel("$x*$",fontsize=15)
plt.title("Diagrama de Bifurcación",fontsize=20)
plt.show()

# %% [markdown]
# ## 3.2.2
# $$\dot{x} = rx - \ln(x+1)$$

# %%
def f(t,x,r,b=0):
  return r*x - np.log(x+1) 

plotVF(f,[-2,0.5,1,2],-0.9,3,10,0,3)

# %%
ti=0; tf=50; dt=100
tspam=[ti, tf]
b=0
plt.figure(figsize=(10,6))
for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-0.9,5,0.7):
    sol=solve_ivp(f,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-0.9,5,0.7):
    sol=solve_ivp(f,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-5, 5, -10, 10])
plt.grid()
plt.xlabel("$r$",fontsize=15)
plt.ylabel("$x*$",fontsize=15)
plt.title("Diagrama de Bifurcación",fontsize=20)
plt.show()

# %% [markdown]
# ## 3.2.3
# $$\dot{x} = x - rx(1-x)$$

# %%
def f(t,x,r,b=0):
  return x-r*x*(1-x) 

plotVF(f,[-2,0,0.5,1,2],-3,3,10,0,3)

# %%
ti=0; tf=100; dt=100
tspam=[ti, tf]
b=0
plt.figure(figsize=(10,6))
for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(f,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(f,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-5, 5, -10, 10])
plt.grid()
plt.xlabel("$r$",fontsize=15)
plt.ylabel("$x*$",fontsize=15)
plt.title("Diagrama de Bifurcación",fontsize=20)
plt.show()

# %% [markdown]
# # 3.4 Pitchfork Bifurcation

# %% [markdown]
# ## 3.4.1
# $$ \dot{x} = rx + 4x^3$$

# %%
def f(t,x,r,b=0):
  return r*x + 4*x**3

plotVF(f,[-4,2],-2,2,10,0,1)

# %%
ti=0; tf=100; dt=100
tspam=[ti, tf]
b=0
plt.figure(figsize=(10,6))
for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(f,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='darkgreen', marker='.')

tspam=[ti, -tf]

for r in np.arange(-5,5,0.2):
  for x0 in np.arange(-5,5,0.7):
    sol=solve_ivp(f,tspam,[x0],args=(r,b))
    plt.scatter(r, sol.y[0][-1], color='red', marker='.')


plt.axis([-5, 5, -2, 2])
plt.grid()
plt.xlabel("$r$",fontsize=15)
plt.ylabel("$x*$",fontsize=15)
plt.title("Diagrama de Bifurcación",fontsize=20)
plt.show()
